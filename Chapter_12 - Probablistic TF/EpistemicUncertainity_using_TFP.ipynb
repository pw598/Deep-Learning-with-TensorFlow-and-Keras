# %%
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

plt.rcParams.update({'font.size': 22})
tfd = tfp.distributions

# %%
def create_dataset(n, x_range):
    x_uniform_dist = tfd.Uniform(low=x_range[0], high=x_range[1])
    x = x_uniform_dist.sample(n).numpy() [:, np.newaxis] 
    y_true = 2.7*x+3
    eps_uniform_dist = tfd.Normal(loc=0, scale=1)
    eps = eps_uniform_dist.sample(n).numpy() [:, np.newaxis] *0.74*x
    y = y_true + eps
    return x, y, y_true

# %%
x_train, y_train, y_true = create_dataset(200, [-10, 10])
x_val, y_val, _ = create_dataset(50, [-10, 10])

# %%
def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  c = np.log(np.expm1(1.))
  return Sequential([
      tfp.layers.VariableLayer(2 * n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t[..., :n],
                     scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
          reinterpreted_batch_ndims=1)),
  ])

# %%
def prior_trainable(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  return Sequential([
      tfp.layers.VariableLayer(n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t, scale=1),
          reinterpreted_batch_ndims=1)),
  ])

# %%
negloglik = lambda y, rv_y: -rv_y.log_prob(y)

# %%
# Build model.
model = Sequential([
  tfp.layers.DenseVariational(1, posterior_mean_field, prior_trainable, kl_weight=1/x_train.shape[0]),
  tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t, scale=1)),
])

# Do inference.
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01), loss=negloglik)
model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 4ms/step - loss: 155.2853
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 189.5845
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 236.8787
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 163.9812
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 144.2197
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 121.6829
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 192.5538
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 163.0956
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 141.0651
# Epoch 10/100
# 7/7 [==============================] - 0s 3ms/step - loss: 138.5887
# Epoch 11/100
# 7/7 [==============================] - 0s 3ms/step - loss: 92.6602
# Epoch 12/100
# 7/7 [==============================] - 0s 3ms/step - loss: 54.0988
# Epoch 13/100
# 7/7 [==============================] - 0s 3ms/step - loss: 80.9495
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 57.0779
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 62.0424
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 48.3894
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 77.6643
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 118.4383
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 74.1817
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 52.0502
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 44.7920
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 39.3347
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 66.9034
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 80.2604
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 61.2758
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 38.0686
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: 38.6399
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 77.3064
# Epoch 29/100
# 7/7 [==============================] - 0s 2ms/step - loss: 35.8943
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 64.7733
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 52.5256
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 47.3245
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: 41.3957
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 35.8115
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 26.6194
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 65.4923
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 36.5323
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 20.9842
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 25.1839
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 15.6302
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 28.9248
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 17.6501
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: 35.4943
# Epoch 44/100
# 7/7 [==============================] - 0s 2ms/step - loss: 32.8528
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 23.0373
# Epoch 46/100
# 7/7 [==============================] - 0s 3ms/step - loss: 40.1777
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 23.3139
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 19.0299
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 22.7753
# Epoch 50/100
# 7/7 [==============================] - 0s 4ms/step - loss: 33.5792
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: 34.5911
# Epoch 52/100
# 7/7 [==============================] - 0s 4ms/step - loss: 23.7092
# Epoch 53/100
# 7/7 [==============================] - 0s 4ms/step - loss: 23.6899
# Epoch 54/100
# 7/7 [==============================] - 0s 4ms/step - loss: 19.4271
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8306
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 36.7751
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1524
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.4426
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 18.2048
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 18.2744
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 16.8092
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 22.1860
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 21.3021
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 17.4369
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 21.7095
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.6938
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5331
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1195
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 18.1372
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 17.1784
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12.6161
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 10.7909
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: 15.1843
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.6126
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 10.9203
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5553
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6338
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 11.5673
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8406
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 17.7420
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1142
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - loss: 11.5590
# Epoch 83/100
# 7/7 [==============================] - 0s 3ms/step - loss: 18.3654
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1965
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0535
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12.7828
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8501
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 11.6757
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12.3003
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6496
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.5079
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1181
# Epoch 93/100
# 7/7 [==============================] - 0s 7ms/step - loss: 11.8235
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 13.2254
# Epoch 95/100
# 7/7 [==============================] - 0s 2ms/step - loss: 11.1313
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 11.8062
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 9.4251
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 11.6396
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 19.2064
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 12.1646

# %%
x_range = [-10, 10]
plt.figure(figsize=[10, 10]) 
plt.clf();
plt.plot(x_train, y_train, 'b.', label='observed');

y_preds = [model(x_val) for _ in range(100)]
avgm = np.zeros_like(x_val[..., 0])
for i, yhat in enumerate(y_preds):
  m = np.squeeze(yhat.mean())
  s = np.squeeze(yhat.stddev())
  if i < 15:
    plt.plot(x_val, m, 'r', label='ensemble means' if i == 0 else None, linewidth=0.5)
  avgm += m
plt.plot(x_val, avgm/len(y_preds), 'g', label='overall mean', linewidth=4)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc='upper left', prop={'size': 20})
